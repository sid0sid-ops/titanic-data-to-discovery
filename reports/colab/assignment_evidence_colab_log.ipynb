# %% [markdown]
# # Student Information
#
# - **Name:** Siddharth Tripathi
# - **Email ID:** sidmsi532004@gmail.com
# - **Enrollment No.:** 473611

# %% [markdown]
# # Colab Session: 349cd9
# Generated from colab-cli history log.

# %% [markdown]
# **Session Created**: 2026-06-21 12:01:55
# - Endpoint: `m-s-kkb-usc1a2-15qeazere7u3`
# - Hardware: `NONE`

# %% [markdown]
# *File Operation*: `upload` on `/content/titanic-assignment-inputs.tar.gz`

# %%
"""Colab CLI wrapper for the assignment evidence generator."""

import os
import runpy
import tarfile
from pathlib import Path

archive = Path("/content/titanic-assignment-inputs.tar.gz")
project = Path("/content")
if not archive.exists():
    raise FileNotFoundError(f"Upload the project input archive to {archive}")

with tarfile.open(archive, "r:gz") as bundle:
    bundle.extractall("/content", filter="data")

os.chdir(project)
os.environ["MPLCONFIGDIR"] = "/tmp/matplotlib-cache"
runpy.run_path(str(project / "scripts" / "generate_assignment_evidence.py"), run_name="__main__")

with tarfile.open("/content/assignment-evidence-colab.tar.gz", "w:gz") as bundle:
    bundle.add(project / "reports", arcname="reports")
    bundle.add(project / "public" / "reports", arcname="public/reports")

print("Remote evidence archive: /content/assignment-evidence-colab.tar.gz")
# Out:
# Generated assignment evidence from Kaggle 891-row training dataset (891 rows).
# Validation accuracy: 0.8156; ROC-AUC: 0.8499
# Reports: /content/reports
# Web copies: /content/public/reports
# Remote evidence archive: /content/assignment-evidence-colab.tar.gz

# %% [markdown]
# *File Operation*: `download` on `/content/assignment-evidence-colab.tar.gz`

# %% [markdown]
# *File Operation*: `upload` on `/content/titanic-assignment-inputs.tar.gz`

# %%
"""Colab CLI wrapper for the assignment evidence generator."""

import os
import runpy
import tarfile
from pathlib import Path

archive = Path("/content/titanic-assignment-inputs.tar.gz")
project = Path("/content")
if not archive.exists():
    raise FileNotFoundError(f"Upload the project input archive to {archive}")

with tarfile.open(archive, "r:gz") as bundle:
    bundle.extractall("/content", filter="data")

os.chdir(project)
os.environ["MPLCONFIGDIR"] = "/tmp/matplotlib-cache"
runpy.run_path(str(project / "scripts" / "generate_assignment_evidence.py"), run_name="__main__")

with tarfile.open("/content/assignment-evidence-colab.tar.gz", "w:gz") as bundle:
    bundle.add(project / "reports", arcname="reports")
    bundle.add(project / "public" / "reports", arcname="public/reports")

print("Remote evidence archive: /content/assignment-evidence-colab.tar.gz")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_2121/3255500226.py in <cell line: 0>()
#      16 os.chdir(project)
#      17 os.environ["MPLCONFIGDIR"] = "/tmp/matplotlib-cache"
# ---> 18 runpy.run_path(str(project / "scripts" / "generate_assignment_evidence.py"), run_name="__main__")
#      19
#      20 with tarfile.open("/content/assignment-evidence-colab.tar.gz", "w:gz") as bundle:
#
# /usr/lib/python3.12/runpy.py in run_path(path_name, init_globals, run_name)
#
# /usr/lib/python3.12/runpy.py in _run_module_code(code, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# /usr/lib/python3.12/runpy.py in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# /content/scripts/generate_assignment_evidence.py in <module>
#      31 sys.path.insert(0, str(ROOT / "src"))
#      32
# ---> 33 from titanic_project.cleaning import clean_assignment_frame, normalize_columns
#      34 from titanic_project.data_loading import load_titanic_data
#      35 from titanic_project.evaluation import classification_metrics
#
# ImportError: cannot import name 'clean_assignment_frame' from 'titanic_project.cleaning' (/content/src/titanic_project/cleaning.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# *File Operation*: `download` on `/content/assignment-evidence-colab.tar.gz`

# %%
"""Colab CLI wrapper for the assignment evidence generator."""

import os
import runpy
import sys
import tarfile
from pathlib import Path

archive = Path("/content/titanic-assignment-inputs.tar.gz")
project = Path("/content")
if not archive.exists():
    raise FileNotFoundError(f"Upload the project input archive to {archive}")

with tarfile.open(archive, "r:gz") as bundle:
    bundle.extractall("/content", filter="data")

os.chdir(project)
os.environ["MPLCONFIGDIR"] = "/tmp/matplotlib-cache"
for module_name in list(sys.modules):
    if module_name == "titanic_project" or module_name.startswith("titanic_project."):
        del sys.modules[module_name]
runpy.run_path(str(project / "scripts" / "generate_assignment_evidence.py"), run_name="__main__")

with tarfile.open("/content/assignment-evidence-colab.tar.gz", "w:gz") as bundle:
    bundle.add(project / "reports", arcname="reports")
    bundle.add(project / "public" / "reports", arcname="public/reports")

print("Remote evidence archive: /content/assignment-evidence-colab.tar.gz")
# Out:
# Generated assignment evidence from Kaggle 891-row training dataset (891 rows).
# Validation accuracy: 0.8156; ROC-AUC: 0.8499
# Reports: reports/
# Web copies: public/reports/
# Remote evidence archive: /content/assignment-evidence-colab.tar.gz

# %% [markdown]
# *File Operation*: `download` on `/content/assignment-evidence-colab.tar.gz`
